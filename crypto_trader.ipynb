# %% [markdown]
# ### Cryptocurrency Trader Agent
# #### Deep Q-Learning Implementation

# %%
# Cryptocurrency Market Simulator

class Crypto_Simulator:
    
    states = ['bollinger', 'rolling20dayMeanReturn', 'volatility']
    actions = ['buy', 'sell', 'hold']
    
    def init(num_steps):
        return
        
    def get_ran_action():
        return 0
        
        
    def step(action):
        state = ''
        reward = 0.0
        return [state, reward]

# %%
# Q Value Function Approximator
# Neural Network Implementation

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras import backend as K

class QValue_NN:
    
    _alpha = None
    _layer = None
    
    # define input and target shapes
    _state_size = None
    _action_size = None
    
    _model = None

    
    # init neural network
    def init(state_size, action_size, learning_rate, units):
        _state_size = state_size
        _action_size = action_size
        _alpha = learning_rate
        _units = units
        _model = _build_model()
    
    
    # define loss function
    def _huber_loss(target, prediction):
        # sqrt(1+error^2)-1
        error = prediction - target
        return K.mean(K.sqrt(1+K.square(error))-1, axis=-1)

    
    # neural net for Deep-Q Learning Model
    def _build_model():
        model = Sequential()
        model.add(Dense(_units, input_dim=_state_size, activation='relu'))
        model.add(Dense(_units, activation='relu'))
        model.add(Dense(_action_size, activation='linear'))
        model.compile(loss=self._huber_loss,
                      optimizer=Adam(lr=_alpha))
        return model

    
    # online training
    def train(states, qvalues):
        _model.fit(state, qvalues, epochs=1, verbose=0)
    
    
    # get q-values based on states
    def predict(states):
        qvalues = _model.predict(state)
        return qvalues
# Out:
# Using TensorFlow backend.

# %%
# Cryptocurrency Trader Q-Learning Implementation

states = ['bollinger', 'rolling20dayMeanReturn', 'volatility']
actions = ['buy', 'sell', 'hold']

class Crypto_Trader:

    def init():
        # Initialize RL parameters

        # Learning Rate
        alpha = 0.1 

        # Reward Discount Rate
        y = 0.95

        # Esiplon (exploration factor)
        esiplon = 0.1

        # Reduce exploration overtime
        esiplon_decay = 0.90

        # number of episodes for training
        num_episodes = 1000

    def train():
        
        sim = Crypto_Simulator()
        nn = QValue_NN(len(states), len(actions), alpha, 24)
        
        for i in range(num_episodes):
            
            #init simulator and get first new observation
            s = sim.init()
            ret = 0
            iteration = 0
            
            #decay Esiplon
            esiplon = esiplon * (esiplon_decay ** iteration)
            
            #Iterate through all experiences and update Q function approximator
            while (1==1):
                
                iteration += 1
                
                #Choose action by e-greedy
                if np.random.rand(1) < esiplon:
                    a = sim.get_ran_action()
                else:
                    #Get Q values, choose action by Q values
                    Qvalues = nn.predict(s)
                    a = np.argmax(Qvalues)
                    
                #step to the next state and reward based on action
                s1,r = sim.step(a)
                
                if (s1 == ''):
                    break
                
                #Get Q values for s1
                Qvalues1 = nn.predict(s1)
                maxQ1 = np.max(Qvalues1)
                
                #Update TargetQ
                targetQ = Qvalues
                targetQ[a] = r + y*maxQ1
                
                #Train NN model online
                nn.train(s, targetQ)
                
                #Update total reward, set s1 to s
                ret += r
                s = s1
                
            print ret
